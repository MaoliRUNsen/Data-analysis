# %% [markdown]
# # Python_DA 期末项目-广州美食数据分析
# * 项目人：邬晓婧
# * 学号：1910130113
# * 时间：2021/7/1
# * 数据源：
#   * [广州美食数据链接](https://www.heywhale.com/mw/dataset/5ee30becb772f5002d75a965/file)
#   * [广州美食店铺地理数据链接](https://www.heywhale.com/mw/dataset/5ee7368271a691002d56a415/file)
# * 目标：为广州用户作出美食店铺数据分析图，供他们选择。

# %% [markdown]
# ## 导入样式

# %%
# %%html
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 45%;
#     height: auto;
#     float: right;
# }
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>
# Out:
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 45%;
#     height: auto;
#     float: right;
# }
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# ## 导入模块

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyecharts import options as opts
from pyecharts.charts import Map

# %% [markdown]
# ## 读取数据

# %%
a_food = pd.read_csv('A网站美食数据.csv',encoding='gbk')
b_food = pd.read_csv('B网站美食数据.csv',encoding='gbk')
local = pd.read_csv('店铺地图信息.csv',encoding='gbk')
city = pd.read_csv('广东美食店铺数量.csv',encoding='gbk')
display(a_food.head())
display(b_food.head())
display(local.head())
display(city.head())
# Out:
#                          名称     评论数  人均价格    类别        商圈  \
# 0               极炙·台灣精致炭火烤肉  3551.0  211元  日本料理  天河城/体育中心
# 1                  大滷爺(正佳店)   151.0   54元    粤菜  天河城/体育中心
# 2              白天鹅宾馆·玉堂春暖餐厅  2018.0  312元    粤菜        沙面
# 3  Mr.Fish鱼鲜生海鲜放题(高德置地冬广场店)  7703.0  354元   自助餐  高德置地/花城汇
# 4          漫活堂·健康有机西餐厅(高志店)  1174.0  148元    西餐   兴盛路/跑马场
#
#                              地址      推荐1        推荐2              推荐3  口味评分  \
# 0       天河路178-188号新天河宾馆院内综合楼3楼   极上和牛套餐       特选牛舌               元贝   9.1
# 1                 体育东路正佳广场五楼广正街    滷爺鹅肉饭      生蚝沙锅粥            卤水鹅肝饭   9.3
# 2                 沙面南街1号白天鹅宾馆3楼      沙琪玛        葵花鸡             招牌虾饺   8.9
# 3  珠江新城花城大道85号高德置地冬广场5楼507-512铺     刺身新鲜      新西兰鳌虾         燕窝哈根达斯雪糕   8.8
# 4           黄埔大道西120号高志大厦首层107铺  低温慢煮牛小排  青苹果焦糖核桃沙拉  鲜虾墨鱼汁意大利面配参巴海鲜酱   9.1
#
#    环境评分  服务评分     星级         店铺ID                                      网址
# 0   8.5   9.2   五星商户     66250176   http://www.dianping.com/shop/66250176
# ...

# %% [markdown]
# ## 合并数据集

# %%
a_food.rename(columns={'名称':'店铺名称','类别':'菜系'},inplace=True) 
# 修改 A 的（名称）列为（店铺名称），（类别）列为（菜系）
a_food['人均价格'] = a_food['人均价格'].str.replace('元','') # （人均价格）的（元）去掉
a_food.head()
# Out:
#                        店铺名称     评论数 人均价格    菜系        商圈  \
# 0               极炙·台灣精致炭火烤肉  3551.0  211  日本料理  天河城/体育中心
# 1                  大滷爺(正佳店)   151.0   54    粤菜  天河城/体育中心
# 2              白天鹅宾馆·玉堂春暖餐厅  2018.0  312    粤菜        沙面
# 3  Mr.Fish鱼鲜生海鲜放题(高德置地冬广场店)  7703.0  354   自助餐  高德置地/花城汇
# 4          漫活堂·健康有机西餐厅(高志店)  1174.0  148    西餐   兴盛路/跑马场
#
#                              地址      推荐1        推荐2              推荐3  口味评分  \
# 0       天河路178-188号新天河宾馆院内综合楼3楼   极上和牛套餐       特选牛舌               元贝   9.1
# 1                 体育东路正佳广场五楼广正街    滷爺鹅肉饭      生蚝沙锅粥            卤水鹅肝饭   9.3
# 2                 沙面南街1号白天鹅宾馆3楼      沙琪玛        葵花鸡             招牌虾饺   8.9
# 3  珠江新城花城大道85号高德置地冬广场5楼507-512铺     刺身新鲜      新西兰鳌虾         燕窝哈根达斯雪糕   8.8
# 4           黄埔大道西120号高志大厦首层107铺  低温慢煮牛小排  青苹果焦糖核桃沙拉  鲜虾墨鱼汁意大利面配参巴海鲜酱   9.1
#
#    环境评分  服务评分     星级         店铺ID                                      网址
# 0   8.5   9.2   五星商户     66250176   http://www.dianping.com/shop/66250176
# ...

# %%
display(a_food.shape)
display(b_food.shape)
food = pd.concat([a_food,b_food],ignore_index=True).drop_duplicates()
display(food.shape) # 纵向合并两个网站数据，去除重复数据
# Out:
# (300, 15)
# (74, 15)
# (374, 15)

# %%
food1 = pd.merge(food,local,on='店铺ID')
food1.shape # 以（店铺ID）为键进行合并，没有 ID 的店铺会丢掉
# Out:
# (372, 19)

# %% [markdown]
# ## 选择需要的列，查看缺失值/类型

# %%
df = food1[['店铺名称','评论数','人均价格','菜系','商圈','推荐1','推荐2','推荐3',
           '口味评分','环境评分','服务评分','星级','纬度','经度','行政区名称']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 0 to 371
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   店铺名称    372 non-null    object
#  1   评论数     372 non-null    float64
#  2   人均价格    372 non-null    object
#  3   菜系      372 non-null    object
#  4   商圈      372 non-null    object
#  5   推荐1     372 non-null    object
#  6   推荐2     372 non-null    object
#  7   推荐3     372 non-null    object
#  8   口味评分    372 non-null    float64
#  9   环境评分    372 non-null    float64
#  10  服务评分    372 non-null    float64
#  11  星级      372 non-null    object
#  12  纬度      372 non-null    float64
#  13  经度      372 non-null    float64
#  14  行政区名称   372 non-null    object
# dtypes: float64(6), object(9)
# memory usage: 46.5+ KB

# %% [markdown]
# ## 广东美食店铺数量分布图

# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Map
datafile = 'C:/Users/86132/Desktop/广州美食数据分析/广东美食店铺数量.csv'
data = pd.read_csv(datafile, encoding = 'gb2312')
city = data['城市'].tolist()
values2 = data['数量'].tolist()

###广东
name = []
value = []
flag = 0
for i in range(0,len(city)):
    if city[i] =="广州市":
        flag = 1
    if flag:
        name.append(city[i])
        value.append(int(values2[i]))

    if city[i] =="云浮市":
        name.append(city[i])
        value.append(int(values2[i]))
        break
c = (
    Map()
        .add("广东美食店铺数量分布", [list(z) for z in zip(name, value)], "广东")
        .set_global_opts(
        title_opts=opts.TitleOpts(title="广东美食店铺数量分布"), visualmap_opts=opts.VisualMapOpts()
    )
  
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="598358faa9aa43a6991a8992391ac5f4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_598358faa9aa43a6991a8992391ac5f4 = echarts.init(
#                     document.getElementById('598358faa9aa43a6991a8992391ac5f4'), 'white', {renderer: 'canvas'});
#                 var option_598358faa9aa43a6991a8992391ac5f4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ## 广州美食地图分布

# %%
from pyecharts.charts import Geo
from pyecharts import options as opts
from pyecharts.globals import GeoType
from pyecharts.globals import ThemeType

g = Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
g.add_schema(maptype='广州')

names = list(df['店铺名称']) # 定义坐标对应的名称，添加到坐标库中 add_coordinate(name, lng, lat)
lng = list(df['经度'])
lat = list(df['纬度'])

for i in range(len(names)):
    g.add_coordinate(names[i],lng[i],lat[i])

data_pair = [(name,50) for name in names]    # 定义数据对

g.add('', data_pair, type_=GeoType.EFFECT_SCATTER, symbol_size=4)  # 将数据添加到地图上

g.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  # 设置样式
g.set_global_opts(
            visualmap_opts=opts.VisualMapOpts(is_show=False),
            title_opts=opts.TitleOpts(title="广州各个地区美食分布"), # 设置标题
        )
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广州':'https://assets.pyecharts.org/assets/maps/guang3_dong1_guang3_zhou1', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="052ad21f132d4bf1b56a753b7705f8c2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广州', 'purple-passion'], function(echarts) {
#                 var chart_052ad21f132d4bf1b56a753b7705f8c2 = echarts.init(
#                     document.getElementById('052ad21f132d4bf1b56a753b7705f8c2'), 'purple-passion', {renderer: 'canvas'});
#                 var option_052ad21f132d4bf1b56a753b7705f8c2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %% [markdown]
# ## 广州哪个区美食最多

# %%
region = df['行政区名称'].value_counts()  # 计算每个行政区的美食数
region
# Out:
# 天河区    164
# 越秀区     69
# 海珠区     68
# 荔湾区     27
# 番禺区     23
# 白云区     20
# 黄埔区      1
# Name: 行政区名称, dtype: int64

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie    # 输入模块绘制饼图
from pyecharts.globals import ThemeType   

x = ['天河区', '越秀区', '海珠区', '荔湾区', '番禺区', '白云区', '黄埔区'] # 输入广州各地区
y = [164, 69, 68, 27, 23, 20, 1]   # 输入每个区对应的美食数量

c = (
        Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add(series_name='', data_pair=[(i, j)for i, j in zip(x, y)]) #遍历数据
        .set_global_opts(title_opts=opts.TitleOpts(title="广州各行政区美食占比")) #输入标题
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
        
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="a2e9b82980944e15820f68cd9002078d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_a2e9b82980944e15820f68cd9002078d = echarts.init(
#                     document.getElementById('a2e9b82980944e15820f68cd9002078d'), 'purple-passion', {renderer: 'canvas'});
#                 var option_a2e9b82980944e15820f68cd9002078d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %% [markdown]
# ## 美食集中在哪些商圈

# %%
bussiness_area = df['商圈'].value_counts()
bussiness_area
# Out:
# 珠江新城         60
# 天河城/体育中心     42
# 北京路          34
# 江南西          23
# 天河北          22
# 高德置地/花城汇     10
# 江南大道         10
# 机场路          10
# 石牌/龙口        10
# 兴盛路/跑马场      10
# 中山七八路         9
# 工业大道          9
# 环市东           9
# 南村            8
# 客村/赤岗         8
# 滨江路           7
# 琶洲            7
# 中山二三路/东山口     6
# 芳村            6
# 沙面            5
# 小北/淘金         5
# 车陂/东圃         4
# 东风东/杨箕        4
# 五羊新城          4
# 市桥            3
# 同和/京溪         3
# 白云绿地中心        3
# 上下九           3
# 越秀公园          3
# 新港西路          3
# 荔湾区           2
# 洛溪            2
# 万达广场          2
# 番禺广场          2
# 天河公园          2
# 天河区           2
# 长隆            2
# 区庄/动物园        1
# 时尚天河          1
# 大石            1
# 海珠广场          1
# 萝岗万达广场        1
# 桥南            1
# 沿江路/二沙岛       1
# 五号停机坪         1
# 厦滘            1
# 天河客运站         1
# 钟村            1
# 东晓南           1
# 西村/西场         1
# 黄石            1
# 康王路           1
# 科学城           1
# 番禺区           1
# 南浦            1
# ...

# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Bar
x = ['珠江新城','天河城/体育中心','北京路','江南西','天河北','机场路',
     '江南大道','高德置地/花城汇','石牌/龙口','兴盛路/跑马场']   # 输入x轴的数值
y = [60, 42, 34, 23, 22, 10, 10, 10, 10, 10]   # 输入y轴对应的美食商家数量
bar=(
        Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add_xaxis(x)
        .add_yaxis("",y)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="广州美食商家分布的商圈"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-12)))
         )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="68d1409f497f4543b66c4aeb6e9d3f90" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_68d1409f497f4543b66c4aeb6e9d3f90 = echarts.init(
#                     document.getElementById('68d1409f497f4543b66c4aeb6e9d3f90'), 'purple-passion', {renderer: 'canvas'});
#                 var option_68d1409f497f4543b66c4aeb6e9d3f90 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %% [markdown]
# ## 商家等级星级分布

# %%
start = df['星级'].value_counts()
start
# Out:
# 四星商户     175
# 准五星商户    156
# 五星商户      34
# 准四星商户      7
# Name: 星级, dtype: int64

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.globals import ThemeType

def pie_circle():
    x = ['四星商户','准五星商户','五星商户','准四星商户']
    y = [175,156,34,7]

c = (
        Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add(
            "",
            [list(z) for z in zip(x,y)],
            radius=["40%", "55%"],
            label_opts=opts.LabelOpts(
                position="outside",
                formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
                background_color="#eee",
                border_color="#aaa",
                border_width=1,
                border_radius=4,
                rich={
                    "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                    "abg": {
                        "backgroundColor": "#e3e3e3",
                        "width": "100%",
                        "align": "right",
                        "height": 22,
                        "borderRadius": [4, 4, 0, 0],
                    },
                    "hr": {
                        "borderColor": "#aaa",
                        "width": "100%",
                        "borderWidth": 0.5,
                        "height": 0,
                    },
                    "b": {"fontSize": 16, "lineHeight": 33},
                    "per": {
                        "color": "#eee",
                        "backgroundColor": "#334455",
                        "padding": [2, 4],
                        "borderRadius": 2,
                    },
                },
            ),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="各区星级商户占比"))
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="aad2f349273f4b099f1bf7a6cd23e0a1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_aad2f349273f4b099f1bf7a6cd23e0a1 = echarts.init(
#                     document.getElementById('aad2f349273f4b099f1bf7a6cd23e0a1'), 'purple-passion', {renderer: 'canvas'});
#                 var option_aad2f349273f4b099f1bf7a6cd23e0a1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %% [markdown]
# ## 广州美食类型

# %%
kind = df['菜系'].value_counts()
kind
# Out:
# 西餐      61
# 粤菜      53
# 日本料理    52
# 火锅      43
# 面包甜点    21
# 自助餐     20
# 烧烤      18
# 咖啡厅     14
# 川菜      11
# 东南亚菜    11
# 韩国料理     9
# 茶餐厅      9
# 创意菜      7
# 韩式料理     6
# 湘菜       6
# 素菜       5
# 小龙虾      4
# 海鲜       4
# 茶餐馆      3
# 其他美食     3
# 江浙菜      3
# 快餐简餐     2
# 台湾菜      2
# 私房菜      1
# 粥粉面      1
# 西北菜      1
# 新疆菜      1
# 家常菜      1
# Name: 菜系, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False   # 这两行代码解决 plt 中文显示的问题

x = ['西餐','粤菜','日本料理','火锅','面包甜点','自助餐','烧烤','咖啡厅','东南亚菜', '川菜']
y = [61,53,52,43,21,20,18,14,11,11,]
x = x[::-1][3:]
y = y[::-1][3:]

c = (
        Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add_xaxis(x)
        .add_yaxis("", y)
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="广州美食种类分布"))
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="b70e1205df044d988e19bd2304aa4ba3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_b70e1205df044d988e19bd2304aa4ba3 = echarts.init(
#                     document.getElementById('b70e1205df044d988e19bd2304aa4ba3'), 'purple-passion', {renderer: 'canvas'});
#                 var option_b70e1205df044d988e19bd2304aa4ba3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %% [markdown]
# ## 广州美食词云分布图

# %%
w1 = list(df['推荐1'])    
w2 = list(df['推荐2'])   # 将所有推荐美食连接起来
w3 = list(df['推荐3'])
w1 = ''.join(w1)
w2 = ''.join(w2)
w3 = ''.join(w3)
txt = w1 + w2 + w3

# 分词
import jieba
ls = jieba.lcut(txt)

# 计算词频
word = {}
for w in ls:
    word[w] = word.get(w,0) + 1

words = list(word.items())

print('连接成功')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\86132\AppData\Local\Temp\jieba.cache
# Loading model cost 0.704 seconds.
# Prefix dict has been built successfully.
# 连接成功

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType
from pyecharts.globals import ThemeType

def worldcloud():
    c = (
        WordCloud(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add("", words, word_size_range=[20, 100], shape=SymbolType.DIAMOND)
        .set_global_opts(title_opts=opts.TitleOpts(title=""))
    )
    return c
worldcloud().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="5479bafd2ea345ce9083b43f59bbaee9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'purple-passion'], function(echarts) {
#                 var chart_5479bafd2ea345ce9083b43f59bbaee9 = echarts.init(
#                     document.getElementById('5479bafd2ea345ce9083b43f59bbaee9'), 'purple-passion', {renderer: 'canvas'});
#                 var option_5479bafd2ea345ce9083b43f59bbaee9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %% [markdown]
# ## 综合评分与人均价格关系

# %%
num = df[['评论数','人均价格','口味评分','环境评分','服务评分']]
num['人均价格'] = num['人均价格'].astype(float)
num_corr = num.corr() # 【人均价格】去掉【元】并转换为 float64，并计算相关性
num_corr
# Out:
# <ipython-input-23-eb0066f6b251>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num['人均价格'] = num['人均价格'].astype(float)
#            评论数      人均价格      口味评分      环境评分      服务评分
# 评论数   1.000000  0.040016 -0.076266 -0.051358 -0.283651
# 人均价格  0.040016  1.000000  0.138383  0.407077  0.337381
# 口味评分 -0.076266  0.138383  1.000000  0.254799  0.523959
# 环境评分 -0.051358  0.407077  0.254799  1.000000  0.689202
# 服务评分 -0.283651  0.337381  0.523959  0.689202  1.000000

# %%
from pyecharts.globals import ThemeType
from pyecharts import options as opts
from pyecharts.charts import HeatMap

def heat_corr():
    # 将上面的相关系数矩阵处理一下
    value = [[0,0,1.00],[0,1,0.04],[0,2,-0.07],[0,3,-0.05],[0,4,-0.28],
             [1,0,0.04],[1,1,1.00],[1,2,0.13],[1,3,0.40],[1,4,0.33],
             [2,0,-0.07],[2,1,0.13],[2,2,1.00],[2,3,0.25],[2,4,0.52],
             [3,0,-0.05],[3,1,0.40],[3,2,0.25],[3,3,1.00],[3,4,0.68],
             [4,0,-0.28],[4,1,0.33],[4,2,0.52],[4,3,0.68],[4,4,1.00]]

    c = (
        HeatMap(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        .add_xaxis(['评论数','人均价格','口味评分','环境评分','服务评分'])
        .add_yaxis(
            "",
            ['评论数','人均价格','口味评分','环境评分','服务评分'],
            value,
            label_opts=opts.LabelOpts(is_show=True, position="inside"),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="评论数，人均价格，口味评分，环境评分，服务评分相关性热力图",
                                     pos_left='center'),
            visualmap_opts=opts.VisualMapOpts(is_show=False,min_=-1,
                                              max_=1),
        )
    )
    return c
heat_corr().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="6b58ef9bedf14e1e8eab554551ee1a59" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_6b58ef9bedf14e1e8eab554551ee1a59 = echarts.init(
#                     document.getElementById('6b58ef9bedf14e1e8eab554551ee1a59'), 'purple-passion', {renderer: 'canvas'});
#                 var option_6b58ef9bedf14e1e8eab554551ee1a59 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %%
'''
综合评分=（口味评分+环境评分+服务评分）/ 3 
'''
score = df[['人均价格','口味评分','环境评分','服务评分']]
score['人均价格'] = score['人均价格'].astype(float)
score['综合评分'] = (score['口味评分']+score['环境评分']+score['服务评分']) / 3
score.head(1)
# Out:
# <ipython-input-25-a6767cfe4b07>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['人均价格'] = score['人均价格'].astype(float)
# <ipython-input-25-a6767cfe4b07>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['综合评分'] = (score['口味评分']+score['环境评分']+score['服务评分']) / 3
#    人均价格  口味评分  环境评分  服务评分      综合评分
# 0  54.0   9.3   9.1   9.1  9.166667

# %%
import pyecharts.options as opts
from pyecharts.charts import Scatter
from pyecharts.globals import ThemeType

def scatter():
    x_data = list(score['人均价格'])
    y_data = list(score['综合评分'])

    c = (
        Scatter(init_opts=opts.InitOpts(width="800px", height="500px",
                                       theme=ThemeType.PURPLE_PASSION))
        .add_xaxis(xaxis_data=x_data)
        .add_yaxis(
            series_name="",
            y_axis=y_data,
            symbol_size=20,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_series_opts()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                type_="value", splitline_opts=opts.SplitLineOpts(is_show=True)
                ,name='人均价格'
            ),
            yaxis_opts=opts.AxisOpts(
                type_="value",
                axistick_opts=opts.AxisTickOpts(is_show=True),
                splitline_opts=opts.SplitLineOpts(is_show=True),
                name='综合评分'
            ),
            tooltip_opts=opts.TooltipOpts(is_show=False),
        )
    )
    return c
scatter().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="36e508275de94bf0a39ab865bd64d560" style="width:800px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_36e508275de94bf0a39ab865bd64d560 = echarts.init(
#                     document.getElementById('36e508275de94bf0a39ab865bd64d560'), 'purple-passion', {renderer: 'canvas'});
#                 var option_36e508275de94bf0a39ab865bd64d560 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %% [markdown]
# ## 总结
# ##### 通过分析广州美食店铺的数据后，经过不同方面的分析，可以得出：
# * 第一 广州餐饮的整体消费水平适中，美食的种类+分丰富，其中西餐、日料和粤.菜在人气评分及口碑方面都表现突出。
# * 第二 从地理位置上看，广州的美食聚集程度较高，主要集中在天河区海珠区和越秀区，其中天河区作为广州的CBD，其商圈密集程度、菜系丰富度以及消费水平都比较高。
# * 第三 在美食推荐方面，广泛探店可以考虑北京路、天河城/体育中心、珠江新城等热门商圈。
