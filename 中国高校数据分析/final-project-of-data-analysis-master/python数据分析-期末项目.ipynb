# %% [markdown]
# # python数据分析期末项目
# - 项目人：黄南辉
# - 时间：2021年7月3日
# - 数据源：本项目使用了两个csv数据文件，一个是中国高校（大学）的数据，一个是中国高校专业设置的数据
# - 分析目标：分析中国目前高校（大学）办学状况、中国开设数量排名前20的热门专业和国家特色专业学校分布等关于高校办学的信息，为报志愿的高考生和想了解这方面信息的人提供参考

# %% [markdown]
# ## 导入所用到的模块

# %%
import pandas as pd 
from collections import Counter
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType
from pyecharts.charts import Pie
from pyecharts.charts import Bar, Timeline

# %% [markdown]
# ## 读取数据

# %%
# 读取学校和专业数据
df_学校 = pd.read_csv('data/school.csv',encoding='gbk')
df_专业 = pd.read_csv('data/professional.csv',encoding='gbk')

# %%
df_学校
# Out:
#                 学校  省份       城市                               地址    水平层次 办学类别  \
# 0     河北轨道运输职业技术学院  河北     石家庄市  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类
# 1             厦门大学  福建      厦门市                福建省厦门市思明区思明南路422号    普通本科  综合类
# 2             四川大学  四川      成都市                  四川省成都市一环路南一段24号    普通本科  综合类
# 3             武汉大学  湖北      武汉市                 湖北省武汉市武昌区八一路299号    普通本科  综合类
# 4             北京大学  北京      北京市                     北京市海淀区颐和园路5号    普通本科  综合类
# ...            ...  ..      ...                              ...     ...  ...
# 2851        甘孜职业学院  四川  甘孜藏族自治州                              NaN  专科（高职）  NaN
# 2852      郑州城建职业学院  河南      郑州市                              NaN  专科（高职）  NaN
# 2853  广西农业工程职业技术学院  广西      南宁市           中国-东盟南宁空港扶绥经济区空港大道东25号  专科（高职）  NaN
# 2854      北海康养职业学院  广西      北海市                  北海市银海区金海岸大道666号  专科（高职）  NaN
# 2855    白银希望职业技术学院  甘肃      白银市                 甘肃省白银市银西生态产业园南京路  专科（高职）  NaN
#
#      办学类型 985 211  双一流   归属                                        开设专业链接
# 0      公办   否   否  NaN  河北省  https://gkcx.eol.cn/school/2858/professional
# 1      公办   是   是    是  教育部   https://gkcx.eol.cn/school/102/professional
# 2      公办   是   是    是  教育部    https://gkcx.eol.cn/school/99/professional
# 3      公办   是   是    是  教育部    https://gkcx.eol.cn/school/42/professional
# 4      公办   是   是    是  教育部    https://gkcx.eol.cn/school/31/professional
# ...   ...  ..  ..  ...  ...                                           ...
# 2851   公办   否   否  NaN  NaN  https://gkcx.eol.cn/school/3595/professional
# 2852   民办   否   否  NaN  NaN  https://gkcx.eol.cn/school/3582/professional
# 2853   公办   否   否  NaN  NaN  https://gkcx.eol.cn/school/3592/professional
# 2854   民办   否   否  NaN  NaN  https://gkcx.eol.cn/school/3593/professional
# 2855   民办   否   否  NaN  NaN  https://gkcx.eol.cn/school/3601/professional
#
# [2856 rows x 12 columns]

# %% [markdown]
# ## 删除无用数据

# %%
df_学校.drop(['归属','开设专业链接'],axis=1,inplace=True)

# %%
df_学校
# Out:
#                 学校  省份       城市                               地址    水平层次 办学类别  \
# 0     河北轨道运输职业技术学院  河北     石家庄市  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类
# 1             厦门大学  福建      厦门市                福建省厦门市思明区思明南路422号    普通本科  综合类
# 2             四川大学  四川      成都市                  四川省成都市一环路南一段24号    普通本科  综合类
# 3             武汉大学  湖北      武汉市                 湖北省武汉市武昌区八一路299号    普通本科  综合类
# 4             北京大学  北京      北京市                     北京市海淀区颐和园路5号    普通本科  综合类
# ...            ...  ..      ...                              ...     ...  ...
# 2851        甘孜职业学院  四川  甘孜藏族自治州                              NaN  专科（高职）  NaN
# 2852      郑州城建职业学院  河南      郑州市                              NaN  专科（高职）  NaN
# 2853  广西农业工程职业技术学院  广西      南宁市           中国-东盟南宁空港扶绥经济区空港大道东25号  专科（高职）  NaN
# 2854      北海康养职业学院  广西      北海市                  北海市银海区金海岸大道666号  专科（高职）  NaN
# 2855    白银希望职业技术学院  甘肃      白银市                 甘肃省白银市银西生态产业园南京路  专科（高职）  NaN
#
#      办学类型 985 211  双一流
# 0      公办   否   否  NaN
# 1      公办   是   是    是
# 2      公办   是   是    是
# 3      公办   是   是    是
# 4      公办   是   是    是
# ...   ...  ..  ..  ...
# 2851   公办   否   否  NaN
# 2852   民办   否   否  NaN
# 2853   公办   否   否  NaN
# 2854   民办   否   否  NaN
# 2855   民办   否   否  NaN
#
# [2856 rows x 10 columns]

# %% [markdown]
# ## 分析各省大学数量分布情况

# %%
print(df_学校[['省份','学校']])
# Out:
#       省份            学校
# 0     河北  河北轨道运输职业技术学院
# 1     福建          厦门大学
# 2     四川          四川大学
# 3     湖北          武汉大学
# 4     北京          北京大学
# ...   ..           ...
# 2851  四川        甘孜职业学院
# 2852  河南      郑州城建职业学院
# 2853  广西  广西农业工程职业技术学院
# 2854  广西      北海康养职业学院
# 2855  甘肃    白银希望职业技术学院
#
# [2856 rows x 2 columns]

# %% [markdown]
# ### 按省份对数据进行分组

# %%
# 使用groupby按省份对学校分组
province_学校 = df_学校.groupby(['省份','学校']).sum()
province_学校
# Out:
#                      城市                   地址    水平层次 办学类别 办学类型 985 211 双一流
# 省份  学校
# 上海  上海东海职业技术学院      上海市      上海市闵行区虹梅南路6001号  专科（高职）  综合类   民办   否   否   0
#     上海中侨职业技术大学      上海市      上海市金山区漕廊公路3888号    普通本科  财经类   民办   否   否   0
#     上海中医药大学         上海市      上海市浦东新区蔡伦路1200号    普通本科  医药类   公办   否   否   是
#     上海交通大学          上海市           上海市东川路800号    普通本科  综合类   公办   是   是   是
#     上海交通大学医学院       上海市          上海市重庆南路227号    普通本科  医药类   公办   否   否   0
# ...                 ...                  ...     ...  ...  ...  ..  ..  ..
# 黑龙江 齐齐哈尔医学院       齐齐哈尔市     齐齐哈尔市建华卜奎北大街333号    普通本科  医药类   公办   否   否   0
#     齐齐哈尔大学        齐齐哈尔市  黑龙江省齐齐哈尔市建华区文化大街42号    普通本科  综合类   公办   否   否   0
#     齐齐哈尔工程学院      齐齐哈尔市       黑龙江省齐齐哈尔市喜庆路1号    普通本科  综合类   民办   否   否   0
#     齐齐哈尔理工职业学院    齐齐哈尔市   齐齐哈尔市富拉尔基区和平大街249号  专科（高职）  理工类   民办   否   否   0
#     齐齐哈尔高等师范专科学校  齐齐哈尔市     黑龙江省齐齐哈尔市民航路566号  专科（高职）  师范类   公办   否   否   0
#
# [2856 rows x 8 columns]

# %% [markdown]
# ### 统计各省学校数量

# %%
# 使用collections的Counter函数统计各省学校数量
province = list(df_学校["省份"])
province_学校数量 = dict(Counter(province))
province_学校数量
# Out:
# {'河北': 126,
#  '福建': 90,
#  '四川': 137,
#  '湖北': 134,
#  '北京': 102,
#  '广东': 163,
#  '湖南': 129,
#  '江苏': 174,
#  '重庆': 73,
#  '浙江': 111,
#  '山东': 160,
#  '天津': 62,
#  '上海': 65,
#  '河南': 158,
#  '吉林': 70,
#  '陕西': 104,
#  '辽宁': 110,
#  '海南': 21,
#  '江西': 108,
#  '黑龙江': 81,
#  '甘肃': 52,
#  '云南': 82,
#  '安徽': 128,
#  '山西': 85,
#  '广西': 85,
#  '贵州': 77,
#  '新疆': 56,
#  '内蒙古': 56,
#  '宁夏': 20,
#  '青海': 12,
#  '西藏': 6,
#  '香港': 14,
#  '澳门': 5}

# %% [markdown]
# ### 构建各省学校数量的DataFrame表格

# %%
省份_list = list(province_学校数量.keys())
省份_list
# Out:
# ['河北',
#  '福建',
#  '四川',
#  '湖北',
#  '北京',
#  '广东',
#  '湖南',
#  '江苏',
#  '重庆',
#  '浙江',
#  '山东',
#  '天津',
#  '上海',
#  '河南',
#  '吉林',
#  '陕西',
#  '辽宁',
#  '海南',
#  '江西',
#  '黑龙江',
#  '甘肃',
#  '云南',
#  '安徽',
#  '山西',
#  '广西',
#  '贵州',
#  '新疆',
#  '内蒙古',
#  '宁夏',
#  '青海',
#  '西藏',
#  '香港',
#  '澳门']

# %%
学校数量_list = list(province_学校数量.values())
学校数量_list
# Out:
# [126,
#  90,
#  137,
#  134,
#  102,
#  163,
#  129,
#  174,
#  73,
#  111,
#  160,
#  62,
#  65,
#  158,
#  70,
#  104,
#  110,
#  21,
#  108,
#  81,
#  52,
#  82,
#  128,
#  85,
#  85,
#  77,
#  56,
#  56,
#  20,
#  12,
#  6,
#  14,
#  5]

# %%
# 构建各省学校数量的DataFrame表格
df_各省学校数量 = pd.DataFrame({'省份':省份_list,'学校数量':学校数量_list})
df_各省学校数量
# Out:
#      省份  学校数量
# 0    河北   126
# 1    福建    90
# 2    四川   137
# 3    湖北   134
# 4    北京   102
# 5    广东   163
# 6    湖南   129
# 7    江苏   174
# 8    重庆    73
# 9    浙江   111
# 10   山东   160
# 11   天津    62
# 12   上海    65
# 13   河南   158
# 14   吉林    70
# 15   陕西   104
# 16   辽宁   110
# 17   海南    21
# 18   江西   108
# 19  黑龙江    81
# 20   甘肃    52
# 21   云南    82
# 22   安徽   128
# 23   山西    85
# 24   广西    85
# 25   贵州    77
# 26   新疆    56
# 27  内蒙古    56
# 28   宁夏    20
# 29   青海    12
# 30   西藏     6
# 31   香港    14
# 32   澳门     5

# %% [markdown]
# ### 绘制各省学校数量可视化图
# - 使用pyecharts的Map函数绘制地图

# %%
p = 省份_list
v = 学校数量_list
c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add("", [list(z) for z in zip(p,v)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="高校分布地区"),
        visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="820f117fea324f278572a5e8b02af0c1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'essos'], function(echarts) {
#                 var chart_820f117fea324f278572a5e8b02af0c1 = echarts.init(
#                     document.getElementById('820f117fea324f278572a5e8b02af0c1'), 'essos', {renderer: 'canvas'});
#                 var option_820f117fea324f278572a5e8b02af0c1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 163
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 174
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 160
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 158
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 82
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 5
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u9ad8\u6821\u5206\u5e03\u5730\u533a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_820f117fea324f278572a5e8b02af0c1.setOption(option_820f117fea324f278572a5e8b02af0c1);
#         });
#     </script>

# %% [markdown]
# ## 分析本科、专科占比情况

# %% [markdown]
# ### 统计本科和专科数量

# %%
df_本专科数量 = df_学校['水平层次'].value_counts().reset_index()
df_本专科数量
# Out:
#     index  水平层次
# 0  专科（高职）  1499
# 1    普通本科  1357

# %%
# 重设列名，获得本专科数量表格
df_本专科数量.rename(columns = {'index':'水平层次','水平层次':'数量'},inplace = True)

# %%
df_本专科数量
# Out:
#      水平层次    数量
# 0  专科（高职）  1499
# 1    普通本科  1357

# %% [markdown]
# ### 构建本科、专科学校表格

# %%
df_本专科学校 = df_学校.groupby(['水平层次','学校']).sum()
df_本专科学校
# Out:
#                       省份     城市                                  地址 办学类别 办学类型  \
# 水平层次   学校
# 专科（高职） 七台河职业学院       黑龙江   七台河市                  黑龙江省七台河市桃山区学府街229号  综合类   公办
#        三亚中瑞酒店管理职业学院   海南    三亚市                    海南省三亚市海棠区湾坡路108号  综合类   民办
#        三亚城市职业学院       海南    三亚市                    海南省三亚市吉阳区抱坡路100号  综合类   民办
#        三亚理工职业学院       海南    三亚市                       海南省三亚市迎宾大道学院路  理工类   民办
#        三亚航空旅游职业学院     海南    三亚市                       海南省三亚市凤凰路218号  理工类   民办
# ...                  ...    ...                                 ...  ...  ...
# 普通本科   齐鲁理工学院         山东    济南市  山东省济南市经十东路3028号,曲阜校区：山东省曲阜市有朋路105号  综合类   民办
#        齐齐哈尔医学院       黑龙江  齐齐哈尔市                    齐齐哈尔市建华卜奎北大街333号  医药类   公办
#        齐齐哈尔大学        黑龙江  齐齐哈尔市                 黑龙江省齐齐哈尔市建华区文化大街42号  综合类   公办
#        齐齐哈尔工程学院      黑龙江  齐齐哈尔市                      黑龙江省齐齐哈尔市喜庆路1号  综合类   民办
#        龙岩学院           福建    龙岩市                        福建省龙岩市东肖北路1号   其他   公办
#
#                     985 211 双一流
# 水平层次   学校
# 专科（高职） 七台河职业学院        否   否   0
#        三亚中瑞酒店管理职业学院   否   否   0
#        三亚城市职业学院       否   否   0
#        三亚理工职业学院       否   否   0
#        三亚航空旅游职业学院     否   否   0
# ...                  ..  ..  ..
# 普通本科   齐鲁理工学院         否   否   0
#        齐齐哈尔医学院        否   否   0
#        齐齐哈尔大学         否   否   0
#        齐齐哈尔工程学院       否   否   0
#        龙岩学院           否   否   0
#
# [2856 rows x 8 columns]

# %% [markdown]
# ### 绘制本科、专科占比可视化图
# - 使用pyecharts的Pie函数绘制饼图

# %%
l = list(df_本专科数量['水平层次'])
v = list(df_本专科数量['数量'])
print(l,v)
# Out:
# ['专科（高职）', '普通本科'] [1499, 1357]

# %%
c = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add(
        "",
        [list(z) for z in zip(l,v)],
        radius=["40%", "75%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="本/专科占比"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="77c4c2d090414d819db87c57a8a2edd7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_77c4c2d090414d819db87c57a8a2edd7 = echarts.init(
#                     document.getElementById('77c4c2d090414d819db87c57a8a2edd7'), 'essos', {renderer: 'canvas'});
#                 var option_77c4c2d090414d819db87c57a8a2edd7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4e13\u79d1\uff08\u9ad8\u804c\uff09",
#                     "value": 1499
#                 },
#                 {
#                     "name": "\u666e\u901a\u672c\u79d1",
#                     "value": 1357
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e13\u79d1\uff08\u9ad8\u804c\uff09",
#                 "\u666e\u901a\u672c\u79d1"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u672c/\u4e13\u79d1\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_77c4c2d090414d819db87c57a8a2edd7.setOption(option_77c4c2d090414d819db87c57a8a2edd7);
#         });
#     </script>

# %% [markdown]
# ## 分析办学类别占比情况

# %% [markdown]
# ### 统计各个办学类别数量

# %%
df_办学类别数量 = df_学校['办学类别'].value_counts().reset_index()
df_办学类别数量
# Out:
#    index  办学类别
# 0    理工类   865
# 1    综合类   828
# 2    师范类   242
# 3    医药类   216
# 4    财经类   216
# 5    艺术类   106
# 6    农林类    87
# 7    政法类    68
# 8    军事类    55
# 9     其他    55
# 10   语言类    38
# 11   体育类    35
# 12   民族类    15

# %%
# 重设列名，获得各个办学类别数量表格
df_办学类别数量.rename(columns = {'index':'办学类别','办学类别':'数量'},inplace = True)

# %%
df_办学类别数量
# Out:
#    办学类别   数量
# 0   理工类  865
# 1   综合类  828
# 2   师范类  242
# 3   医药类  216
# 4   财经类  216
# 5   艺术类  106
# 6   农林类   87
# 7   政法类   68
# 8   军事类   55
# 9    其他   55
# 10  语言类   38
# 11  体育类   35
# 12  民族类   15

# %% [markdown]
# ### 构建各个办学类别学校表格

# %%
df_办学类别学校 = df_学校.groupby(['办学类别','学校']).sum()
df_办学类别学校
# Out:
#                     省份     城市                                        地址  \
# 办学类别 学校
# 体育类  上海体育学院         上海    上海市                            上海市杨浦区清源环路650号
#      云南体育运动职业技术学院   云南    昆明市                               云南昆明海埂体院路3号
#      内蒙古体育职业学院     内蒙古  呼和浩特市                      内蒙古呼和浩特市新城区成吉思汗大街19号
#      北京体育大学         北京    北京市                              北京市海淀区信息路48号
#      北京体育职业学院       北京    北京市      院本部：北京市丰台区光彩北路4号,分校区：北京市大兴区芦城乡政府路21号
# ...                ...    ...                                       ...
# 财经类  陕西财经职业技术学院     陕西    咸阳市                               陕西省咸阳市文林路1号
#      首都经济贸易大学       北京    北京市  校本部位于北京市丰台区花乡张家路口121号,红庙校区位于北京市朝阳门外金台里2号
#      黑龙江商业职业学院     黑龙江   牡丹江市                       黑龙江省牡丹江市爱民区西圣林街333号
#      黑龙江旅游职业技术学院   黑龙江   哈尔滨市                        黑龙江省哈尔滨市南岗区学府路315号
#      黑龙江财经学院       黑龙江   哈尔滨市                           哈尔滨市利民开发区学院路99号
#
#                      水平层次 办学类型 985 211 双一流
# 办学类别 学校
# 体育类  上海体育学院          普通本科   公办   否   否   是
#      云南体育运动职业技术学院  专科（高职）   公办   否   否   0
#      内蒙古体育职业学院     专科（高职）   公办   否   否   0
#      北京体育大学          普通本科   公办   否   是   是
#      北京体育职业学院      专科（高职）   公办   否   否   0
# ...                   ...  ...  ..  ..  ..
# 财经类  陕西财经职业技术学院    专科（高职）   公办   否   否   0
#      首都经济贸易大学        普通本科   公办   否   否   0
#      黑龙江商业职业学院     专科（高职）   公办   否   否   0
#      黑龙江旅游职业技术学院   专科（高职）   公办   否   否   0
#      黑龙江财经学院         普通本科   民办   否   否   0
#
# [2826 rows x 8 columns]

# %% [markdown]
# ### 绘制各个办学类别占比可视化图
# - 使用pyecharts的Pie函数绘制饼图

# %%
l = list(df_办学类别数量['办学类别'])
v = list(df_办学类别数量['数量'])
print(l,v)
# Out:
# ['理工类', '综合类', '师范类', '医药类', '财经类', '艺术类', '农林类', '政法类', '军事类', '其他', '语言类', '体育类', '民族类'] [865, 828, 242, 216, 216, 106, 87, 68, 55, 55, 38, 35, 15]

# %%
c = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add(
        "",
        [list(z) for z in zip(l,v)],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="办学类别占比"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="da4a9534ff734f29bdf132adbef9c735" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_da4a9534ff734f29bdf132adbef9c735 = echarts.init(
#                     document.getElementById('da4a9534ff734f29bdf132adbef9c735'), 'essos', {renderer: 'canvas'});
#                 var option_da4a9534ff734f29bdf132adbef9c735 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7406\u5de5\u7c7b",
#                     "value": 865
#                 },
#                 {
#                     "name": "\u7efc\u5408\u7c7b",
#                     "value": 828
#                 },
#                 {
#                     "name": "\u5e08\u8303\u7c7b",
#                     "value": 242
#                 },
#                 {
#                     "name": "\u533b\u836f\u7c7b",
#                     "value": 216
#                 },
#                 {
#                     "name": "\u8d22\u7ecf\u7c7b",
#                     "value": 216
#                 },
#                 {
#                     "name": "\u827a\u672f\u7c7b",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u519c\u6797\u7c7b",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u653f\u6cd5\u7c7b",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u519b\u4e8b\u7c7b",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u8bed\u8a00\u7c7b",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u4f53\u80b2\u7c7b",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u6c11\u65cf\u7c7b",
#                     "value": 15
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7406\u5de5\u7c7b",
#                 "\u7efc\u5408\u7c7b",
#                 "\u5e08\u8303\u7c7b",
#                 "\u533b\u836f\u7c7b",
#                 "\u8d22\u7ecf\u7c7b",
#                 "\u827a\u672f\u7c7b",
#                 "\u519c\u6797\u7c7b",
#                 "\u653f\u6cd5\u7c7b",
#                 "\u519b\u4e8b\u7c7b",
#                 "\u5176\u4ed6",
#                 "\u8bed\u8a00\u7c7b",
#                 "\u4f53\u80b2\u7c7b",
#                 "\u6c11\u65cf\u7c7b"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u529e\u5b66\u7c7b\u522b\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_da4a9534ff734f29bdf132adbef9c735.setOption(option_da4a9534ff734f29bdf132adbef9c735);
#         });
#     </script>

# %% [markdown]
# ## 985，211，双一流院校数量对比

# %% [markdown]
# ### 统计985，211，双一流院校数量

# %%
su_985 = df_学校[df_学校['985'] == '是'].shape[0]
su_211 = df_学校[df_学校['211'] == '是'].shape[0]
su_yiliu = int(df_学校['双一流'].value_counts().values[0])
print(su_985,su_211,su_yiliu)
# Out:
# 46 126 148

# %%
重点院校类别_list = ['985','211','双一流']
重点院校数量_list = [su_985,su_211,su_yiliu]

# %%
df_重点院校数量 = pd.DataFrame({'重点院校类别':重点院校类别_list,'重点院校数量':重点院校数量_list})
df_重点院校数量
# Out:
#   重点院校类别  重点院校数量
# 0    985      46
# 1    211     126
# 2    双一流     148

# %% [markdown]
# ### 绘制重点院校数量可视化图
# - 使用pyecharts的Bar函数绘制柱状图

# %%
c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(['985','211','双一流'])
    .add_yaxis("",[su_985,su_211,su_yiliu])
    .set_global_opts(title_opts=opts.TitleOpts(title="重点大学数量对比"))

)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="5b4164eb87524683a1fd4bf75e68c37b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_5b4164eb87524683a1fd4bf75e68c37b = echarts.init(
#                     document.getElementById('5b4164eb87524683a1fd4bf75e68c37b'), 'essos', {renderer: 'canvas'});
#                 var option_5b4164eb87524683a1fd4bf75e68c37b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 46,
#                 126,
#                 148
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "985",
#                 "211",
#                 "\u53cc\u4e00\u6d41"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u91cd\u70b9\u5927\u5b66\u6570\u91cf\u5bf9\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5b4164eb87524683a1fd4bf75e68c37b.setOption(option_5b4164eb87524683a1fd4bf75e68c37b);
#         });
#     </script>

# %% [markdown]
# ## 分析985，211，双一流分布情况

# %% [markdown]
# ### 统计985，211，双一流学校及分布

# %%
# 统计985学校及分布
df_985 = df_学校[df_学校['985'] == '是']
df_985学校及分布 = df_985.groupby(['省份','学校']).sum()
df_985学校及分布
# Out:
#                     城市                                                 地址  \
# 省份  学校
# 上海  上海交通大学         上海市                                         上海市东川路800号
#     华东师范大学         上海市                                       上海市中山北路3663号
#     同济大学           上海市                                        上海市四平路1239号
#     复旦大学           上海市                                      上海市杨浦区邯郸路220号
#     复旦大学上海医学院      上海市                                        上海市医学院路138号
# 北京  中国人民大学         北京市                                     北京市海淀区中关村大街59号
#     中国农业大学         北京市                                      北京市海淀区清华东路17号
#     中央民族大学         北京市                                    北京市海淀区中关村南大街27号
#     北京大学           北京市                                       北京市海淀区颐和园路5号
#     北京大学医学部        北京市                                北京市海淀区学院路38号北京大学医学部
#     北京师范大学         北京市                                 北太平庄校区北京市新街口外大街19号
#     北京理工大学         北京市                                     北京市海淀区中关村南大街5号
#     北京航空航天大学       北京市               学院路校区：北京市海淀区学院路37号;沙河校区：北京市昌平区沙河高教园区
#     清华大学           北京市                                        北京市海淀区清华园1号
# 吉林  吉林大学           长春市                 前卫南区：长春市前进大街2699号;前卫北区：长春市解放大路123号
# 四川  四川大学           成都市                                    四川省成都市一环路南一段24号
#     电子科技大学         成都市                                成都市高新区（西区）西源大道2006号
#     电子科技大学格拉斯哥学院   成都市                   成都市高新区（西区）西源大道2006号电子科技大学主楼A1区3楼
# 天津  南开大学           天津市                                       天津市南开区卫津路94号
#     天津大学           天津市                                       天津市南开区卫津路92号
# 安徽  中国科学技术大学       合肥市                                       安徽省合肥市金寨路96号
# 山东  中国海洋大学         青岛市                                   山东省青岛市崂山区松岭路238号
#     哈尔滨工业大学（威海）    威海市                                    山东省威海市环翠区文化西路2号
#     山东大学           济南市                                      山东省济南市山大南路27号
#     山东大学（威海）       威海市                                  山东省威海市环翠区文化西路180号
# 广东  中山大学           广州市                                     广东省广州市新港西路135号
#     华南理工大学         广州市  广东省广州市天河区五山路381号（五山校区）,广州市番禺区广州大学城外环东路382号（大学城...
#     哈尔滨工业大学（深圳）    深圳市                   广东省深圳市南山区西丽深圳大学城哈工大深圳研究生院B栋202A室
# 江苏  东南大学           南京市                                      南京市江宁区东南大学路2号
#     南京大学           南京市          仙林校区地址：江苏省南京市仙林大道163号;鼓楼校区地址：江苏省南京市汉口路22号
# 河北  东北大学秦皇岛分校     秦皇岛市                               河北省秦皇岛经济技术开发区泰山路143号
# 浙江  浙江大学           杭州市                                  浙江省杭州市西湖区余杭塘路388号
# 湖北  华中科技大学         武汉市                   湖北省武汉市洪山区珞喻路1037号;湖北省武汉市汉口航空路13号
#     武汉大学           武汉市                                   湖北省武汉市武昌区八一路299号
# 湖南  中南大学           长沙市                                     湖南省长沙市麓山南路932号
#     国防科技大学         长沙市                                湖南省长沙市国防科学技术大学招生办公室
#     湖南大学           长沙市                                   湖南省长沙市岳麓区麓山南路麓山门
# 甘肃  兰州大学           兰州市                                        兰州市天水南路222号
# 福建  厦门大学           厦门市                                  福建省厦门市思明区思明南路422号
# 辽宁  东北大学           沈阳市                                  辽宁省沈阳市和平区文化路三巷11号
#     大连理工大学         大连市                                    辽宁省大连市甘井子区凌工路2号
# 重庆  重庆大学           重庆市                                     重庆市沙坪坝区沙正街174号
# 陕西  西北农林科技大学       咸阳市                            陕西杨凌国家农业高新技术产业示范区西农路22号
#     西北工业大学         西安市                                        西安市友谊西路127号
#     西安交通大学         西安市                                         西安市咸宁西路28号
# 黑龙江 哈尔滨工业大学       哈尔滨市                                 黑龙江省哈尔滨市南岗区西大直街92号
#
#                   水平层次 办学类别    办学类型 985 211 双一流
# 省份  学校
# 上海  上海交通大学        普通本科  综合类      公办   是   是   是
#     华东师范大学        普通本科  师范类      公办   是   是   是
#     同济大学          普通本科  综合类      公办   是   是   是
#     复旦大学          普通本科  综合类      公办   是   是   是
#     复旦大学上海医学院     普通本科  医药类      公办   是   是   0
# 北京  中国人民大学        普通本科  综合类      公办   是   是   是
#     中国农业大学        普通本科  农林类      公办   是   是   是
#     中央民族大学        普通本科  民族类      公办   是   是   是
#     北京大学          普通本科  综合类      公办   是   是   是
#     北京大学医学部       普通本科  医药类      公办   是   是   0
#     北京师范大学        普通本科  师范类      公办   是   是   是
#     北京理工大学        普通本科  理工类      公办   是   是   是
#     北京航空航天大学      普通本科  理工类      公办   是   是   是
#     清华大学          普通本科  综合类      公办   是   是   是
# 吉林  吉林大学          普通本科  综合类      公办   是   是   是
# 四川  四川大学          普通本科  综合类      公办   是   是   是
#     电子科技大学        普通本科  理工类      公办   是   是   是
#     电子科技大学格拉斯哥学院  普通本科  理工类  中外合作办学   是   是   是
# 天津  南开大学          普通本科  综合类      公办   是   是   是
#     天津大学          普通本科  理工类      公办   是   是   是
# 安徽  中国科学技术大学      普通本科  理工类      公办   是   是   是
# 山东  中国海洋大学        普通本科  综合类      公办   是   是   是
#     哈尔滨工业大学（威海）   普通本科  理工类      公办   是   是   是
#     山东大学          普通本科  综合类      公办   是   是   是
#     山东大学（威海）      普通本科  综合类      公办   是   是   是
# 广东  中山大学          普通本科  综合类      公办   是   是   是
#     华南理工大学        普通本科  理工类      公办   是   是   是
#     哈尔滨工业大学（深圳）   普通本科  理工类      公办   是   是   是
# 江苏  东南大学          普通本科  综合类      公办   是   是   是
#     南京大学          普通本科  综合类      公办   是   是   是
# 河北  东北大学秦皇岛分校     普通本科  理工类      公办   是   是   0
# 浙江  浙江大学          普通本科  综合类      公办   是   是   是
# 湖北  华中科技大学        普通本科  理工类      公办   是   是   是
#     武汉大学          普通本科  综合类      公办   是   是   是
# 湖南  中南大学          普通本科  综合类      公办   是   是   是
#     国防科技大学        普通本科  军事类      公办   是   是   是
#     湖南大学          普通本科  综合类      公办   是   是   是
# 甘肃  兰州大学          普通本科  综合类      公办   是   是   是
# 福建  厦门大学          普通本科  综合类      公办   是   是   是
# 辽宁  东北大学          普通本科  理工类      公办   是   是   是
#     大连理工大学        普通本科  理工类      公办   是   是   是
# 重庆  重庆大学          普通本科  综合类      公办   是   是   是
# 陕西  西北农林科技大学      普通本科  农林类      公办   是   是   是
#     西北工业大学        普通本科  理工类      公办   是   是   是
#     西安交通大学        普通本科  综合类      公办   是   是   是
# 黑龙江 哈尔滨工业大学       普通本科  理工类      公办   是   是   是

# %%
# 统计211学校及分布
df_211 = df_学校[df_学校['211'] == '是']
df_211学校及分布 = df_211.groupby(['省份','学校']).sum()
df_211学校及分布
# Out:
#                城市                                    地址  水平层次 办学类别 办学类型 985  \
# 省份  学校
# 上海  上海交通大学    上海市                            上海市东川路800号  普通本科  综合类   公办   是
#     上海外国语大学   上海市                        上海市虹口区大连西路550号  普通本科  语言类   公办   否
#     上海大学      上海市  宝山校区：上海市宝山区上大路99号;延长校区：上海市静安区延长路149号  普通本科  综合类   公办   否
#     上海财经大学    上海市                         上海市杨浦区国定路777号  普通本科  财经类   公办   否
#     东华大学      上海市                          上海市延安西路1882号  普通本科  理工类   公办   否
# ...           ...                                   ...   ...  ...  ...  ..
# 青海  青海大学      西宁市                         青海省西宁市宁大路251号  普通本科  综合类   公办   否
# 黑龙江 东北农业大学   哈尔滨市                    黑龙江省哈尔滨市香坊区长江路600号  普通本科  农林类   公办   否
#     东北林业大学   哈尔滨市                     黑龙江省哈尔滨市香坊区和兴路26号  普通本科  农林类   公办   否
#     哈尔滨工业大学  哈尔滨市                    黑龙江省哈尔滨市南岗区西大直街92号  普通本科  理工类   公办   是
#     哈尔滨工程大学  哈尔滨市                       哈尔滨市南岗区南通大街145号  普通本科  理工类   公办   否
#
#             211 双一流
# 省份  学校
# 上海  上海交通大学    是   是
#     上海外国语大学   是   是
#     上海大学      是   是
#     上海财经大学    是   是
#     东华大学      是   是
# ...          ..  ..
# 青海  青海大学      是   是
# 黑龙江 东北农业大学    是   是
#     东北林业大学    是   是
#     哈尔滨工业大学   是   是
#     哈尔滨工程大学   是   是
#
# [126 rows x 8 columns]

# %%
# 统计双一流学校及分布
df_双一流 = df_学校[df_学校['双一流'] == '是']
df_双一流学校及分布 = df_双一流.groupby(['省份','学校']).sum()
df_双一流学校及分布
# Out:
#                城市                                    地址  水平层次 办学类别 办学类型 985  \
# 省份  学校
# 上海  上海中医药大学   上海市                       上海市浦东新区蔡伦路1200号  普通本科  医药类   公办   否
#     上海交通大学    上海市                            上海市东川路800号  普通本科  综合类   公办   是
#     上海体育学院    上海市                        上海市杨浦区清源环路650号  普通本科  体育类   公办   否
#     上海外国语大学   上海市                        上海市虹口区大连西路550号  普通本科  语言类   公办   否
#     上海大学      上海市  宝山校区：上海市宝山区上大路99号;延长校区：上海市静安区延长路149号  普通本科  综合类   公办   否
# ...           ...                                   ...   ...  ...  ...  ..
# 青海  青海大学      西宁市                         青海省西宁市宁大路251号  普通本科  综合类   公办   否
# 黑龙江 东北农业大学   哈尔滨市                    黑龙江省哈尔滨市香坊区长江路600号  普通本科  农林类   公办   否
#     东北林业大学   哈尔滨市                     黑龙江省哈尔滨市香坊区和兴路26号  普通本科  农林类   公办   否
#     哈尔滨工业大学  哈尔滨市                    黑龙江省哈尔滨市南岗区西大直街92号  普通本科  理工类   公办   是
#     哈尔滨工程大学  哈尔滨市                       哈尔滨市南岗区南通大街145号  普通本科  理工类   公办   否
#
#             211 双一流
# 省份  学校
# 上海  上海中医药大学   否   是
#     上海交通大学    是   是
#     上海体育学院    否   是
#     上海外国语大学   是   是
#     上海大学      是   是
# ...          ..  ..
# 青海  青海大学      是   是
# 黑龙江 东北农业大学    是   是
#     东北林业大学    是   是
#     哈尔滨工业大学   是   是
#     哈尔滨工程大学   是   是
#
# [148 rows x 8 columns]

# %% [markdown]
# ### 绘制重点学校分布可视化图
# - 使用pyecharts的Bar函数绘制条形图

# %%
tl = Timeline(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
for i in ['985','211','双一流']:
    p_v = df_学校[df_学校[i] == '是']
    p_v = p_v['省份'].value_counts().reset_index()[:10]
    p = list(p_v['index'])[::-1]
    v = list(p_v['省份'])[::-1]
    bar = (
        Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        .add_xaxis(p)
        .add_yaxis("数量",v, label_opts=opts.LabelOpts(position="right"))
        .reversal_axis()
        .set_global_opts(
            title_opts=opts.TitleOpts("重点大学分布轮播图".format(i))
        )
    )
    tl.add(bar, "{}".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="00c9970bee044a06b13e53375d5b68d1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_00c9970bee044a06b13e53375d5b68d1 = echarts.init(
#                     document.getElementById('00c9970bee044a06b13e53375d5b68d1'), 'essos', {renderer: 'canvas'});
#                 var option_00c9970bee044a06b13e53375d5b68d1 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u6570\u91cf",
#                 "legendHoverLink": true,
#                 "data": [
#                     4,
#                     5,
#                     6,
#                     6,
#                     7,
#                     7,
#                     9,
#                     14,
#                     16,
#                     35
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "right",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "985",
#                 "211",
#                 "\u53cc\u4e00\u6d41"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u6e56\u5357",
#                     "\u5c71\u4e1c",
#                     "\u5e7f\u4e1c",
#                     "\u5929\u6d25",
#                     "\u6e56\u5317",
#                     "\u9655\u897f",
#                     "\u56db\u5ddd",
#                     "\u4e0a\u6d77",
#                     "\u6c5f\u82cf",
#                     "\u5317\u4eac"
#                 ]
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u6570\u91cf"
#                     ],
#                     "selected": {
#                         "\u6570\u91cf": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "\u6570\u91cf",
#                     "legendHoverLink": true,
#                     "data": [
#                         2,
#                         2,
#                         2,
#                         3,
#                         3,
#                         3,
#                         3,
#                         4,
#                         5,
#                         9
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "right",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     }
#                 }
#             ],
#             "yAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "\u6e56\u5317",
#                         "\u5929\u6d25",
#                         "\u8fbd\u5b81",
#                         "\u6e56\u5357",
#                         "\u5e7f\u4e1c",
#                         "\u9655\u897f",
#                         "\u56db\u5ddd",
#                         "\u5c71\u4e1c",
#                         "\u4e0a\u6d77",
#                         "\u5317\u4eac"
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u91cd\u70b9\u5927\u5b66\u5206\u5e03\u8f6e\u64ad\u56fe",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDe

# %% [markdown]
# ## 分析开设数量前二十的专业

# %%
df_专业
# Out:
#                  学校        专业类别      专业名称 国家特色专业
# 0      河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN
# 1      河北轨道运输职业技术学院    土建施工类(专)    建筑工程技术    NaN
# 2      河北轨道运输职业技术学院  机械设计制造类(专)      数控技术    NaN
# 3      河北轨道运输职业技术学院    机电设备类(专)    电梯工程技术    NaN
# 4      河北轨道运输职业技术学院     自动化类(专)   机电一体化技术    NaN
# ...             ...         ...       ...    ...
# 91895    林州建筑职业技术学院    建筑设计类(专)  建筑装饰工程技术    NaN
# 91896    林州建筑职业技术学院    土建施工类(专)    建筑工程技术    NaN
# 91897    林州建筑职业技术学院  建设工程管理类(专)      工程造价    NaN
# 91898    林州建筑职业技术学院  建设工程管理类(专)    建设工程监理    NaN
# 91899    林州建筑职业技术学院    财务会计类(专)        会计    NaN
#
# [91900 rows x 4 columns]

# %% [markdown]
# ### 获取开设数量前20的专业数据

# %%
top20 = df_专业['专业名称'].value_counts().reset_index()
专业名称 = list(top20['index'])[:20]
数量 = list(top20['专业名称'])[:20]
print(专业名称,数量)
# Out:
# ['市场营销', '电子商务', '物流管理', '旅游管理', '财务管理', '会计', '国际经济与贸易', '计算机科学与技术', '工程造价', '英语', '商务英语', '视觉传达设计', '酒店管理', '环境设计', '机电一体化技术', '学前教育', '电子信息工程', '会计学', '人力资源管理', '计算机应用技术'] [1279, 1209, 1053, 1041, 950, 857, 811, 808, 799, 783, 672, 656, 648, 644, 621, 610, 597, 588, 557, 557]

# %% [markdown]
# ### 构建开设数量前20的专业数据表格

# %%
df_top20专业 = pd.DataFrame({'专业名称':专业名称,'开设总数':数量})
df_top20专业
# Out:
#         专业名称  开设总数
# 0       市场营销  1279
# 1       电子商务  1209
# 2       物流管理  1053
# 3       旅游管理  1041
# 4       财务管理   950
# 5         会计   857
# 6    国际经济与贸易   811
# 7   计算机科学与技术   808
# 8       工程造价   799
# 9         英语   783
# 10      商务英语   672
# 11    视觉传达设计   656
# 12      酒店管理   648
# 13      环境设计   644
# 14   机电一体化技术   621
# 15      学前教育   610
# 16    电子信息工程   597
# 17       会计学   588
# 18    人力资源管理   557
# 19   计算机应用技术   557

# %% [markdown]
# ### 绘制开设数量前20的专业可视化图
# - 使用pyecharts的Bar函数绘制柱状图

# %%
c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(
        专业名称
    )
    .add_yaxis("", 数量)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
        title_opts=opts.TitleOpts(title="开设专业top20"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="659707684a1f42dcbebcad6b7aba5996" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_659707684a1f42dcbebcad6b7aba5996 = echarts.init(
#                     document.getElementById('659707684a1f42dcbebcad6b7aba5996'), 'essos', {renderer: 'canvas'});
#                 var option_659707684a1f42dcbebcad6b7aba5996 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 1279,
#                 1209,
#                 1053,
#                 1041,
#                 950,
#                 857,
#                 811,
#                 808,
#                 799,
#                 783,
#                 672,
#                 656,
#                 648,
#                 644,
#                 621,
#                 610,
#                 597,
#                 588,
#                 557,
#                 557
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e02\u573a\u8425\u9500",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u7269\u6d41\u7ba1\u7406",
#                 "\u65c5\u6e38\u7ba1\u7406",
#                 "\u8d22\u52a1\u7ba1\u7406",
#                 "\u4f1a\u8ba1",
#                 "\u56fd\u9645\u7ecf\u6d4e\u4e0e\u8d38\u6613",
#                 "\u8ba1\u7b97\u673a\u79d1\u5b66\u4e0e\u6280\u672f",
#                 "\u5de5\u7a0b\u9020\u4ef7",
#                 "\u82f1\u8bed",
#                 "\u5546\u52a1\u82f1\u8bed",
#                 "\u89c6\u89c9\u4f20\u8fbe\u8bbe\u8ba1",
#                 "\u9152\u5e97\u7ba1\u7406",
#                 "\u73af\u5883\u8bbe\u8ba1",
#                 "\u673a\u7535\u4e00\u4f53\u5316\u6280\u672f",
#                 "\u5b66\u524d\u6559\u80b2",
#                 "\u7535\u5b50\u4fe1\u606f\u5de5\u7a0b",
#                 "\u4f1a\u8ba1\u5b66",
#                 "\u4eba\u529b\u8d44\u6e90\u7ba1\u7406",
#                 "\u8ba1\u7b97\u673a\u5e94\u7528\u6280\u672f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5f00\u8bbe\u4e13\u4e1atop20",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_659707684a1f42dcbebcad6b7aba5996.setOption(option_659707684a1f42dcbebcad6b7aba5996);
#         });
#     </script>

# %% [markdown]
# ## 分析国家特色专业学校分布情况

# %% [markdown]
# ### 获取各学校国家特色专业数量数据

# %%
tese = df_专业[df_专业['国家特色专业'] == '是']
tese = tese.groupby('学校').count()['国家特色专业'].reset_index()
tese = tese.sort_values(by='国家特色专业',ascending=False)
tese
# Out:
#          学校  国家特色专业
# 107    北京大学      41
# 420    浙江大学      32
# 4    上海交通大学      28
# 349    武汉大学      28
# 184    吉林大学      26
# ..      ...     ...
# 500  福建警察学院       1
# 501    红河学院       1
# 503    绥化学院       1
# 203    嘉应学院       1
# 628    龙岩学院       1
#
# [629 rows x 2 columns]

# %% [markdown]
# ### 绘制国家特色专业数量排名前20的学校可视化图
# - 使用pyecharts的Bar函数绘制柱状图

# %%
school = list(tese['学校'])[:20]
values = list(tese['国家特色专业'])[:20]

# %%
c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
    .add_xaxis(
        school
    )
    .add_yaxis("", values)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
        title_opts=opts.TitleOpts(title="特色专业top20"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="102c18689e5f4dc8b782f2f527b8b50e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_102c18689e5f4dc8b782f2f527b8b50e = echarts.init(
#                     document.getElementById('102c18689e5f4dc8b782f2f527b8b50e'), 'essos', {renderer: 'canvas'});
#                 var option_102c18689e5f4dc8b782f2f527b8b50e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 41,
#                 32,
#                 28,
#                 28,
#                 26,
#                 25,
#                 25,
#                 24,
#                 22,
#                 22,
#                 21,
#                 21,
#                 20,
#                 19,
#                 19,
#                 19,
#                 19,
#                 18,
#                 18,
#                 18
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac\u5927\u5b66",
#                 "\u6d59\u6c5f\u5927\u5b66",
#                 "\u4e0a\u6d77\u4ea4\u901a\u5927\u5b66",
#                 "\u6b66\u6c49\u5927\u5b66",
#                 "\u5409\u6797\u5927\u5b66",
#                 "\u5929\u6d25\u5927\u5b66",
#                 "\u5c71\u4e1c\u5927\u5b66",
#                 "\u534e\u4e2d\u79d1\u6280\u5927\u5b66",
#                 "\u56db\u5ddd\u5927\u5b66",
#                 "\u6e05\u534e\u5927\u5b66",
#                 "\u5927\u8fde\u7406\u5de5\u5927\u5b66",
#                 "\u897f\u5b89\u4ea4\u901a\u5927\u5b66",
#                 "\u5357\u4eac\u5927\u5b66",
#                 "\u897f\u5357\u5927\u5b66",
#                 "\u4e2d\u5357\u5927\u5b66",
#                 "\u54c8\u5c14\u6ee8\u5de5\u4e1a\u5927\u5b66",
#                 "\u5317\u4eac\u5916\u56fd\u8bed\u5927\u5b66",
#                 "\u540c\u6d4e\u5927\u5b66",
#                 "\u534e\u5357\u7406\u5de5\u5927\u5b66",
#                 "\u4e2d\u56fd\u4eba\u6c11\u5927\u5b66"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7279\u8272\u4e13\u4e1atop20",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_102c18689e5f4dc8b782f2f527b8b50e.setOption(option_102c18689e5f4dc8b782f2f527b8b50e);
#         });
#     </script>
